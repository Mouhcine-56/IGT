# %%
# epoch 10000 for HJB
# c1 = 1-exp(t-1)
# c2 = exp(t-1)
# %run main.py
# Out:
# Approximate solution by HJB
#
# Iteration 0: Loss = 6.9200e-01
# Iteration 1000: Loss = 1.3228e-02
# Iteration 2000: Loss = 6.0237e-04
# Iteration 3000: Loss = 1.0441e-04
# Iteration 4000: Loss = 2.6940e-05
# Iteration 5000: Loss = 1.2024e-05
# Iteration 6000: Loss = 6.0234e-06
# Iteration 7000: Loss = 3.3903e-06
# Iteration 8000: Loss = 2.3797e-06
# Iteration 9000: Loss = 1.3144e-06
# Iteration 10000: Loss = 7.7835e-07
# HJb_Solved in 46.2 sec
#
# Relative_Error_t0 =  tensor(0.0004, device='cuda:0')
# Relative_Error_t0.5 =  tensor(0.0002, device='cuda:0')
# Relative_Error_tf =  tensor(0., device='cuda:0')
# Round:  0
#
# Generating data...
# Generated 17075 data from 128 BVP solutions in 8.0 sec
#
# Approximate solution of BVP
#
# Iteration 0: Loss_V = 3.3931e-08, Loss_V_x = 3.2201e-06, Loss_HJB = 9.6525e-07, Loss_total = 4.2193e-06
# Iteration 1000: Loss_V = 3.6843e-09, Loss_V_x = 4.2161e-07, Loss_HJB = 6.7527e-07, Loss_total = 1.1006e-06
# ...
